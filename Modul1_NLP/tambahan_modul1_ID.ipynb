# %% [markdown]
# ## Modul Praktikum Pengolahan Bahasa Alami

# %% [markdown]
# Inisialisasi

# %%
import spacy

# %%
nlp = spacy.load("id_nusantara")

# %%
sample_text = "Presiden Joko Widodo tersenyum gembira ketika Kereta Cepat␣Jakarta-Bandung atau KCJB bisa meraih kecepatan 350 kilometer per jam␣sehingga jarak 142,3 km jalur kereta cepat tersebut bisa ditempuh hanya␣dalam waktu 30 menit. Penunjuk kecepatan kereta dengan angka 350 km/h muncul␣di layar yang terpajang di bagian atas pintu penghubung antargerbong.␣Presiden menegaskan kereta tersebut tetap nyaman digunakan, bahkan saat␣mencapai kecepatan maksimal yang diperbolehkan, yaitu 350 km/jam."

# %%
doc = nlp(sample_text)

# %% [markdown]
# Tokenisasi

# %%
for sent in doc.sents:
        print(sent.text)
# Out:
# Presiden Joko Widodo tersenyum gembira ketika Kereta Cepat␣Jakarta-Bandung atau KCJB bisa meraih kecepatan 350 kilometer per jam␣sehingga jarak 142,3 km jalur kereta cepat tersebut bisa ditempuh hanya␣dalam waktu 30 menit.
# Penunjuk kecepatan kereta dengan angka 350 km/h muncul␣di layar yang terpajang di bagian atas pintu penghubung antargerbong.␣Presiden menegaskan kereta tersebut tetap nyaman digunakan, bahkan saat␣mencapai kecepatan maksimal yang diperbolehkan, yaitu 350 km/jam.

# %%
sentences = [sent for sent in doc.sents]

# %%
sample_sent = sentences[0]

# %%
print(sample_sent)
# Out:
# Presiden Joko Widodo tersenyum gembira ketika Kereta Cepat␣Jakarta-Bandung atau KCJB bisa meraih kecepatan 350 kilometer per jam␣sehingga jarak 142,3 km jalur kereta cepat tersebut bisa ditempuh hanya␣dalam waktu 30 menit.

# %% [markdown]
# Langkah 2: Tokenisasi Kata

# %%
for token in sentences[0]:
    print(token.text)
# Out:
# Presiden
# Joko
# Widodo
# tersenyum
# gembira
# ketika
# Kereta
# Cepat
# ␣
# Jakarta
# -
# Bandung
# atau
# KCJB
# bisa
# meraih
# kecepatan
# 350
# kilometer
# per
# jam
# ␣
# sehingga
# jarak
# 142,3
# km
# jalur
# kereta
# cepat
# tersebut
# bisa
# ditempuh
# hanya
# ␣
# dalam
# waktu
# 30
# menit
# .

# %% [markdown]
# Lematisasi

# %%
for token in sentences[0]:
    print(token.text, token.lemma_)
# Out:
# Presiden presiden
# Joko joko
# Widodo widodo
# tersenyum tersenyum
# gembira gembira
# ketika ketika
# Kereta kereta
# Cepat cepat
# ␣ ␣
# Jakarta jakarta
# - -
# Bandung bandung
# atau atau
# KCJB KCJB
# bisa bisa
# meraih raih
# kecepatan cepat
# 350 350
# kilometer kilometer
# per per
# jam jam
# ␣ ␣
# sehingga sehingga
# jarak jarak
# 142,3 142,3
# km km
# jalur jalur
# kereta kereta
# cepat cepat
# tersebut tersebut
# bisa bisa
# ditempuh tempuh
# hanya hanya
# ␣ ␣
# dalam dalam
# waktu waktu
# 30 30
# menit menit
# . .

# %%
for token in sentences[0]:
    print(token.text, token.norm_)
# Out:
# Presiden presiden
# Joko joko
# Widodo widodo
# tersenyum tersenyum
# gembira gembira
# ketika ketika
# Kereta kereta
# Cepat cepat
# ␣ ␣
# Jakarta jakarta
# - -
# Bandung bandung
# atau atau
# KCJB kcjb
# bisa bisa
# meraih meraih
# kecepatan kecepatan
# 350 350
# kilometer kilometer
# per per
# jam jam
# ␣ ␣
# sehingga sehingga
# jarak jarak
# 142,3 142,3
# km km
# jalur jalur
# kereta kereta
# cepat cepat
# tersebut tersebut
# bisa bisa
# ditempuh ditempuh
# hanya hanya
# ␣ ␣
# dalam dalam
# waktu waktu
# 30 30
# menit menit
# . .

# %% [markdown]
# Tagging

# %%
for token in sentences[0]:
    print(token.text, token.pos_)
# Out:
# Presiden PROPN
# Joko PROPN
# Widodo PROPN
# tersenyum VERB
# gembira NOUN
# ketika SCONJ
# Kereta PROPN
# Cepat PROPN
# ␣ PROPN
# Jakarta PROPN
# - PUNCT
# Bandung PROPN
# atau CCONJ
# KCJB PROPN
# bisa AUX
# meraih VERB
# kecepatan NOUN
# 350 NUM
# kilometer NOUN
# per DET
# jam NOUN
# ␣ PROPN
# sehingga SCONJ
# jarak NOUN
# 142,3 NUM
# km NOUN
# jalur NOUN
# kereta NOUN
# cepat ADJ
# tersebut DET
# bisa AUX
# ditempuh VERB
# hanya ADV
# ␣ PROPN
# dalam ADP
# waktu NOUN
# 30 NUM
# menit NOUN
# . PUNCT

# %% [markdown]
# Langkah 2: POS Tagging (Fine-grained part-of-speech)

# %%
for token in sentences[0]:
    print(token.text, token.tag_)
# Out:
# Presiden NSD
# Joko F--
# Widodo F--
# tersenyum X--
# gembira VSA
# ketika S--
# Kereta NSD
# Cepat ASP
# ␣ X--
# Jakarta NSD
# - Z--
# Bandung NSD
# atau H--
# KCJB X--
# bisa M--
# meraih VSA
# kecepatan NSD
# 350 CC-
# kilometer F--
# per R--
# jam NSD
# ␣ X--
# sehingga S--
# jarak ASP
# 142,3 CC-
# km F--
# jalur NSD
# kereta NSD
# cepat ASP
# tersebut B--
# bisa M--
# ditempuh VSP
# hanya D--
# ␣ X--
# dalam ASP
# waktu NSD
# 30 CC-
# menit NSD
# . Z--

# %% [markdown]
# Parsing

# %%
for token in sentences[0]:
    print(token.text, token.dep_)
# Out:
# Presiden nsubj
# Joko flat:name
# Widodo flat:name
# tersenyum ROOT
# gembira obj
# ketika case
# Kereta nsubj
# Cepat flat:name
# ␣ flat:name
# Jakarta flat:name
# - punct
# Bandung flat:name
# atau cc
# KCJB conj
# bisa aux
# meraih dep
# kecepatan obj
# 350 nummod
# kilometer nummod
# per det
# jam compound
# ␣ nmod
# sehingga case
# jarak nsubj:pass
# 142,3 nummod
# km dep
# jalur compound
# kereta compound
# cepat amod
# tersebut det
# bisa aux
# ditempuh parataxis
# hanya advmod
# ␣ obj
# dalam case
# waktu obl
# 30 nummod
# menit nmod
# . punct

# %%
from spacy import displacy
displacy.render(sentences[0], style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="id" id="670c413d5558432388a367b919791107-0" class="displacy" width="6525" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Presiden</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Joko</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# ...

# %%
sentence_spans = list(doc.sents)
displacy.render(sentence_spans, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="id" id="de56f8f3b95241dca5de36fa8792e19f-0" class="displacy" width="6525" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Presiden</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Joko</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# ...

# %% [markdown]
# Case Identification

# %%
for token in sentences[0]:
    print(token.text, token.lower_)
# Out:
# Presiden presiden
# Joko joko
# Widodo widodo
# tersenyum tersenyum
# gembira gembira
# ketika ketika
# Kereta kereta
# Cepat cepat
# ␣ ␣
# Jakarta jakarta
# - -
# Bandung bandung
# atau atau
# KCJB kcjb
# bisa bisa
# meraih meraih
# kecepatan kecepatan
# 350 350
# kilometer kilometer
# per per
# jam jam
# ␣ ␣
# sehingga sehingga
# jarak jarak
# 142,3 142,3
# km km
# jalur jalur
# kereta kereta
# cepat cepat
# tersebut tersebut
# bisa bisa
# ditempuh ditempuh
# hanya hanya
# ␣ ␣
# dalam dalam
# waktu waktu
# 30 30
# menit menit
# . .

# %% [markdown]
# Morphology

# %%
for token in sentences[0]:
    print(token.text, token.morph)
# Out:
# Presiden
# Joko
# Widodo
# tersenyum
# gembira
# ketika
# Kereta
# Cepat
# ␣
# Jakarta
# -
# Bandung
# atau
# KCJB
# bisa
# meraih Mood=Ind|Voice=Act
# kecepatan Number=Sing
# 350 NumType=Card
# kilometer
# per PronType=Tot
# jam Number=Sing
# ␣
# sehingga
# jarak
# 142,3 NumType=Card
# km
# jalur Number=Sing
# kereta Number=Sing
# cepat
# tersebut PronType=Dem
# bisa
# ditempuh Mood=Ind|Voice=Pass
# hanya
# ␣
# dalam
# waktu Number=Sing
# 30 NumType=Card
# menit Number=Sing
# .

# %% [markdown]
# Unguided

# %%
import pandas as pd

# %%
df_sms=pd.read_csv('dataset_sms_spam _v1.csv')

# %%
df_sms.head()
# Out:
#                                                 Teks  label
# 0  [PROMO] Beli paket Flash mulai 1GB di MY TELKO...      2
# 1  2.5 GB/30 hari hanya Rp 35 Ribu Spesial buat A...      2
# 2  2016-07-08 11:47:11.Plg Yth, sisa kuota Flash ...      2
# 3  2016-08-07 11:29:47.Plg Yth, sisa kuota Flash ...      2
# 4  4.5GB/30 hari hanya Rp 55 Ribu Spesial buat an...      2

# %%
df_sms.shape
# Out:
# (1143, 2)

# %% [markdown]
# Mengambil data kalimat pada kolom teks dan menampung ke dalam array (sen-
# tences)

# %%
sentences = []
for index, row in df_sms.iterrows():
    sentences.append(str(row["Teks"]))

# %%
sentences[0:10]
# Out:
# ['[PROMO] Beli paket Flash mulai 1GB di MY TELKOMSEL APP dpt EXTRA kuota 2GB 4G LTE dan EXTRA nelpon hingga 100mnt/1hr. Buruan, cek  di tsel.me/mytsel1 S&K',
#  '2.5 GB/30 hari hanya Rp 35 Ribu Spesial buat Anda yang terpilih. Aktifkan sekarang juga di *550*905#. Promo sd 30 Nov 2015.Buruan aktifkan sekarang. S&K',
#  '2016-07-08 11:47:11.Plg Yth, sisa kuota Flash Anda 478KB. Download MyTelkomsel apps di http://tsel.me/tsel utk cek kuota&beli paket Flash atau hub *363#',
#  '2016-08-07 11:29:47.Plg Yth, sisa kuota Flash Anda 7160KB. Download MyTelkomsel apps di http://tsel.me/tsel utk cek kuota&beli paket Flash atau hub *363#',
#  '4.5GB/30 hari hanya Rp 55 Ribu Spesial buat anda yang terpilih. Aktifkan sekarang juga di *550*907# Buruan..! SKB',
#  '5 HARI LAGI ! EKSTRA Pulsa 50rb dg beli paket internet bulanan di MyTelkomsel utk pembelian pertama sjk 25Aug-25Sept. Cek detail promo di tsel.me/mytsel1',
# ...

# %% [markdown]
# Normalisasi

# %%
import re

# %%
def remove_characters_before_tokenization(sentence,keep_apostrophes=False):
    sentence = sentence.strip()
    if keep_apostrophes:
        PATTERN = r'[?|$|&|*|%|@|(|)|~|#|]'
        filtered_sentence = re.sub(PATTERN, r'', sentence)
    else:
        PATTERN = r'[^a-zA-Z0-9 ]'
        filtered_sentence = re.sub(PATTERN, r'', sentence)
    return filtered_sentence

filtered_list_2 = [remove_characters_before_tokenization(sentence)
                    for sentence in sentences]

# %%
print (filtered_list_2[0:5])
# Out:
# ['PROMO Beli paket Flash mulai 1GB di MY TELKOMSEL APP dpt EXTRA kuota 2GB 4G LTE dan EXTRA nelpon hingga 100mnt1hr Buruan cek  di tselmemytsel1 SK', '25 GB30 hari hanya Rp 35 Ribu Spesial buat Anda yang terpilih Aktifkan sekarang juga di 550905 Promo sd 30 Nov 2015Buruan aktifkan sekarang SK', '20160708 114711Plg Yth sisa kuota Flash Anda 478KB Download MyTelkomsel apps di httptselmetsel utk cek kuotabeli paket Flash atau hub 363', '20160807 112947Plg Yth sisa kuota Flash Anda 7160KB Download MyTelkomsel apps di httptselmetsel utk cek kuotabeli paket Flash atau hub 363', '45GB30 hari hanya Rp 55 Ribu Spesial buat anda yang terpilih Aktifkan sekarang juga di 550907 Buruan SKB']

# %%
cleaned_corpus = [remove_characters_before_tokenization(sentence,keep_apostrophes=True)
for sentence in sentences]

# %%
print (cleaned_corpus[0:5])
# Out:
# ['[PROMO] Beli paket Flash mulai 1GB di MY TELKOMSEL APP dpt EXTRA kuota 2GB 4G LTE dan EXTRA nelpon hingga 100mnt/1hr. Buruan, cek  di tsel.me/mytsel1 SK', '2.5 GB/30 hari hanya Rp 35 Ribu Spesial buat Anda yang terpilih. Aktifkan sekarang juga di 550905. Promo sd 30 Nov 2015.Buruan aktifkan sekarang. SK', '2016-07-08 11:47:11.Plg Yth, sisa kuota Flash Anda 478KB. Download MyTelkomsel apps di http://tsel.me/tsel utk cek kuotabeli paket Flash atau hub 363', '2016-08-07 11:29:47.Plg Yth, sisa kuota Flash Anda 7160KB. Download MyTelkomsel apps di http://tsel.me/tsel utk cek kuotabeli paket Flash atau hub 363', '4.5GB/30 hari hanya Rp 55 Ribu Spesial buat anda yang terpilih. Aktifkan sekarang juga di 550907 Buruan..! SKB']

# %% [markdown]
# Expand Contractions

# %%
from contractions_id import CONTRACTION_MAP

# %%
def expand_contractions(sentence, contraction_mapping):
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())),flags=re.IGNORECASE|re.DOTALL)
    
    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contraction_mapping.get(match)\
                                if contraction_mapping.get(match)\
                                else contraction_mapping.get(match.lower())
        if expanded_contraction!=None:
            expanded_contraction = first_char+expanded_contraction[1:]
        return expanded_contraction
    expanded_sentence = contractions_pattern.sub(expand_match, sentence)
    return expanded_sentence

# %%
expanded_corpus = [expand_contractions(sentence, CONTRACTION_MAP) for sentence in cleaned_corpus]
print (expanded_corpus[0:5])
print("-------------------------------------------------------")
print (CONTRACTION_MAP)
# Out:
# ['[PROMO] Beli pakait Flash mulai 1GB di MY TELKOMSEL APP dpt EXTRA kuota 2GB 4G LTE dan EXTRA nelpon hingga 100mnt/1hr. Buruan, cek  di tsel.me/mytsel1 SK', '2.5 GB/30 hari hanya Rp 35 Ribu Spesial buat Anda yang terpilih. Aktifkan sekarang juga di 550905. Promo sd 30 Nov 2015.Buruan aktifkan sekarang. SK', '2016-07-08 11:47:11.Plg Yth, sisa kuota Flash Anda 478KB. Download MyTelkomsel apps di http://tsel.me/tsel untuk cek kuotabeli pakait Flash atau hub 363', '2016-08-07 11:29:47.Plg Yth, sisa kuota Flash Anda 7160KB. Download MyTelkomsel apps di http://tsel.me/tsel untuk cek kuotabeli pakait Flash atau hub 363', '4.5GB/30 hari hanya Rp 55 Ribu Spesial buat anda yang terpilih. Aktifkan sekarang juga di 550907 Buruan..! SKB']
# -------------------------------------------------------
# ...

# %% [markdown]
# Removing Stop words

# %%
def remove_stopwords(sentences):
    doc = nlp(sentences)
    filtered_tokens = []
    for sent in doc.sents:
        for token in sent:
            if token.is_stop==False:
                filtered_tokens.append(token.text)
    return filtered_tokens

filtered_list_3 =[remove_stopwords(sentence) for sentence in expanded_corpus]
print (filtered_list_3[0:5])
# Out:
# [['[', 'PROMO', ']', 'Beli', 'pakait', 'Flash', '1', 'GB', 'MY', 'TELKOMSEL', 'APP', 'dpt', 'EXTRA', 'kuota', '2', 'GB', '4', 'G', 'LTE', 'EXTRA', 'nelpon', '100mnt/1hr', '.', 'Buruan', ',', 'cek', ' ', 'tsel.me/mytsel1', 'SK'], ['2.5', 'GB/30', 'Rp', '35', 'Ribu', 'Spesial', 'terpilih', '.', 'Aktifkan', '550905', '.', 'Promo', 'sd', '30', 'Nov', '2015.Buruan', 'aktifkan', '.', 'SK'], ['2016', '-', '07', '-', '08', '11:47:11.Plg', 'Yth', ',', 'sisa', 'kuota', 'Flash', '478', 'KB', '.', 'Download', 'MyTelkomsel', 'apps', 'http://tsel.me/tsel', 'cek', 'kuotabeli', 'pakait', 'Flash', 'hub', '363'], ['2016', '-', '08', '-', '07', '11:29:47.Plg', 'Yth', ',', 'sisa', 'kuota', 'Flash', '7160', 'KB', '.', 'Download', 'MyTelkomsel', 'apps', 'http://tsel.me/tsel', 'cek', 'kuotabeli', 'pakait', 'Flash', 'hub', '363'], ['4.5GB/30', 'Rp', '55', 'Ribu', 'Spesial', 'terpilih', '.', 'Aktifkan', '550907', 'Buruan', '..', '!', 'SKB']]

# %% [markdown]
# Lemmatization

# %%
doc = nlp(expanded_corpus[0])

# %%
for sent in doc.sents:
    for token in sent:
        print(token.text, token.lemma_)
# Out:
# [ [
# PROMO PROMO
# ] ]
# Beli beli
# pakait pakait
# Flash flash
# mulai mulai
# 1 1
# GB GB
# di di
# MY MY
# TELKOMSEL TELKOMSEL
# APP APP
# dpt dpt
# EXTRA EXTRA
# kuota kuota
# 2 2
# GB GB
# 4 4
# G G
# LTE LTE
# dan dan
# EXTRA EXTRA
# nelpon nelpon
# hingga hingga
# 100mnt/1hr 100mnt/1hr
# . .
# Buruan buruan
# , ,
# cek cek
#
# di di
# tsel.me/mytsel1 tsel.me/mytsel1
# SK sK

# %%
for sent in doc.sents:
    for token in sent:
        print(token.text, token.norm_)
# Out:
# [ [
# PROMO promo
# ] ]
# Beli beli
# pakait pakait
# Flash flash
# mulai mulai
# 1 1
# GB gb
# di di
# MY my
# TELKOMSEL telkomsel
# APP app
# dpt dpt
# EXTRA extra
# kuota kuota
# 2 2
# GB gb
# 4 4
# G g
# LTE lte
# dan dan
# EXTRA extra
# nelpon nelpon
# hingga hingga
# 100mnt/1hr 100mnt/1hr
# . .
# Buruan buruan
# , ,
# cek cek
#
# di di
# tsel.me/mytsel1 tsel.me/mytsel1
# SK sk

# %% [markdown]
# POS Tagging

# %%
for sent in doc.sents:
    for token in sent:
        print(token.text, token.pos_)
# Out:
# [ PUNCT
# PROMO PROPN
# ] PUNCT
# Beli PROPN
# pakait NOUN
# Flash PROPN
# mulai VERB
# 1 NUM
# GB NOUN
# di ADP
# MY PROPN
# TELKOMSEL PROPN
# APP PROPN
# dpt ADP
# EXTRA PROPN
# kuota NOUN
# 2 NUM
# GB PROPN
# 4 NUM
# G PROPN
# LTE PROPN
# dan CCONJ
# EXTRA PROPN
# nelpon NOUN
# hingga ADP
# 100mnt/1hr NUM
# . PUNCT
# Buruan PROPN
# , PUNCT
# cek PROPN
#   PROPN
# di ADP
# tsel.me/mytsel1 PROPN
# SK PROPN

# %%
for sent in doc.sents:
    for token in sent:
        print(token.text, token.tag_)
# Out:
# [ Z--
# PROMO X--
# ] Z--
# Beli X--
# pakait X--
# Flash X--
# mulai VSA
# 1 CC-
# GB F--
# di R--
# MY X--
# TELKOMSEL X--
# APP F--
# dpt F--
# EXTRA X--
# kuota NSD
# 2 CC-
# GB F--
# 4 CC-
# G F--
# LTE X--
# dan H--
# EXTRA X--
# nelpon NSD
# hingga R--
# 100mnt/1hr CC-
# . Z--
# Buruan NSD
# , Z--
# cek X--
#   X--
# di R--
# tsel.me/mytsel1 X--
# SK X--

# %% [markdown]
# Dependency Parsing

# %%
for sent in doc.sents:
    for token in sent:
        print(token.text, token.dep_)
# Out:
# [ punct
# PROMO nsubj
# ] punct
# Beli flat:name
# pakait flat:name
# Flash nmod
# mulai ROOT
# 1 nummod
# GB obj
# di case
# MY obl
# TELKOMSEL flat:name
# APP flat:name
# dpt flat:name
# EXTRA nmod
# kuota flat:name
# 2 nummod
# GB nummod
# 4 nummod
# G flat:name
# LTE flat:name
# dan cc
# EXTRA conj
# nelpon acl
# hingga case
# 100mnt/1hr nummod
# . punct
# Buruan ROOT
# , punct
# cek conj
#   flat:name
# di case
# tsel.me/mytsel1 nmod
# SK nmod

# %%
from spacy import displacy
for sent in doc.sents:
    displacy.render(sent, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="id" id="bdef32e5d96f4ce7bc77a6b52fbfbc1b-0" class="displacy" width="4425" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">[</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">PROMO]</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
# ...
